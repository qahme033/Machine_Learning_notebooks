% %%
addpath ("../../functions/Neural_Networks/A1/")
% [text, id] = lastwarn()
warning('off', "Octave:data-file-in-path")

% %%
load dataset1
whos
% Out:
% Variables in the current scope:
%
%    Attr Name                     Size                     Bytes  Class
%    ==== ====                     ====                     =====  =====
%         ans                      1x5                          5  char
%         neg_examples_nobias      4x2                         64  double
%         pos_examples_nobias      4x2                         64  double
%         w_gen_feas               3x1                         24  double
%         w_init                   3x1                         24  double
%
% Total is 27 elements using 181 bytes

% %%
%plot -f png 
w = learn_perceptron(neg_examples_nobias,pos_examples_nobias,w_init,w_gen_feas)
% Out:
% Number of errors in iteration 0:	5
% weights:	[-0.621701473780905;0.760915272851413;0.771872048918481]
% <Press enter to continue, q to quit.>
% w =
%
%    3.0526
%   -1.8172
%   -1.2281

% %%
load dataset2
whos
% Out:
% Variables in the current scope:
%
%    Attr Name                     Size                     Bytes  Class
%    ==== ====                     ====                     =====  =====
%         ans                      1x5                          5  char
%         neg_examples_nobias      5x2                         80  double
%         pos_examples_nobias      5x2                         80  double
%         w                        3x1                         24  double
%         w_gen_feas               0x0                          0  double
%         w_init                   3x1                         24  double
%
% Total is 31 elements using 213 bytes

% %%
%plot -f png 
w = learn_perceptron(neg_examples_nobias,pos_examples_nobias,w_init,w_gen_feas)
% Out:
% Number of errors in iteration 0:	3
% weights:	[1.84689886710588;-0.583249292142825;-0.541788825941023]
% <Press enter to continue, q to quit.>
% Number of errors in iteration 100:	3
% weights:	[2.0811845813916;-0.0383987938039716;1.45821117405898]
% <Press enter to continue, q to quit.>q
% w =
%
%    2.081185
%   -0.038399
%    1.458211

% %%
load dataset3
whos
% Out:
% Variables in the current scope:
%
%    Attr Name                     Size                     Bytes  Class
%    ==== ====                     ====                     =====  =====
%         ans                      1x1                          8  double
%         neg_examples_nobias      7x2                        112  double
%         pos_examples_nobias      7x2                        112  double
%         w                        3x1                         24  double
%         w_gen_feas               3x1                         24  double
%         w_init                   3x1                         24  double
%
% Total is 38 elements using 304 bytes

% %%
%plot -f png 
w = learn_perceptron(neg_examples_nobias,pos_examples_nobias,w_init,w_gen_feas)
% Out:
% Number of errors in iteration 0:	7
% weights:	[0.903680337198885;-0.490875491718683;0.948552948288397]
% <Press enter to continue, q to quit.>
% w =
%
%   -0.0077482
%   -4.2649619
%   -0.0514471

% %%
load dataset4
whos
% Out:
% Variables in the current scope:
%
%    Attr Name                     Size                     Bytes  Class
%    ==== ====                     ====                     =====  =====
%         ans                      1x1                          8  double
%         neg_examples_nobias      9x2                        144  double
%         pos_examples_nobias      8x2                        128  double
%         w                        3x1                         24  double
%         w_gen_feas               0x0                          0  double
%         w_init                   3x1                         24  double
%
% Total is 41 elements using 328 bytes

% %%
%plot -f png 
w = learn_perceptron(neg_examples_nobias,pos_examples_nobias,w_init,w_gen_feas)
% Out:
% Number of errors in iteration 0:	7
% weights:	[-0.0318259642363354;-0.255112727796561;-0.00710252200304726]
% <Press enter to continue, q to quit.>
% Number of errors in iteration 100:	8
% weights:	[1.14245975004937;0.123624813731681;0.992897477996953]
% <Press enter to continue, q to quit.>
% Number of errors in iteration 200:	5
% weights:	[1.74531689290651;-0.308268873975958;-0.00710252200304717]
% <Press enter to continue, q to quit.>
% Number of errors in iteration 300:	4
% weights:	[0.408174035763652;-0.135511398892899;-0.00710252200304717]
% <Press enter to continue, q to quit.>q
% w =
%
%    0.4081740
%   -0.1355114
%   -0.0071025
